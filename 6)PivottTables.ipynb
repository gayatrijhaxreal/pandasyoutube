# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Pivot Tables

# %%
data = {
    'Date': pd.date_range('2023-01-01', periods=20),
    'Product': ['A', 'B', 'C', 'D'] * 5,
    'Region': ['East', 'West', 'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West',
               'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West', 'North', 'South'],
    'Sales': np.random.randint(100, 1000, 20),
    'Units': np.random.randint(10, 100, 20),
    'Rep': ['John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary',
            'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice']
}

df = pd.DataFrame(data)

df['Month'] = df['Date'].dt.month_name()
df['Quarter'] = 'Q' + df['Date'].dt.quarter.astype(str)
df
# Out:
#          Date Product Region  Sales  Units    Rep    Month Quarter
# 0  2023-01-01       A   East    786     51   John  January      Q1
# 1  2023-01-02       B   West    472     19   Mary  January      Q1
# 2  2023-01-03       C  North    561     24    Bob  January      Q1
# 3  2023-01-04       D  South    569     55  Alice  January      Q1
# 4  2023-01-05       A   East    549     27   John  January      Q1
# 5  2023-01-06       B   West    633     61   Mary  January      Q1
# 6  2023-01-07       C  North    457     43    Bob  January      Q1
# 7  2023-01-08       D  South    787     51  Alice  January      Q1
# 8  2023-01-09       A   East    565     26   John  January      Q1
# 9  2023-01-10       B   West    666     16   Mary  January      Q1
# 10 2023-01-11       C  North    465     12    Bob  January      Q1
# 11 2023-01-12       D  South    191     45  Alice  January      Q1
# 12 2023-01-13       A   East    634     11   John  January      Q1
# 13 2023-01-14       B   West    148     55   Mary  January      Q1
# 14 2023-01-15       C  North    528     62    Bob  January      Q1
# 15 2023-01-16       D  South    135     22  Alice  January      Q1
# 16 2023-01-17       A   East    182     20   John  January      Q1
# 17 2023-01-18       B   West    186     32   Mary  January      Q1
# 18 2023-01-19       C  North    657     76    Bob  January      Q1
# 19 2023-01-20       D  South    601     54  Alice  January      Q1

# %%
pd.pivot_table(df,values="Sales",index="Region" , columns="Product",aggfunc="median")
# Out:
# Product      A      B      C      D
# Region
# East     565.0    NaN    NaN    NaN
# North      NaN    NaN  528.0    NaN
# South      NaN    NaN    NaN  569.0
# West       NaN  472.0    NaN    NaN

# %%
pivot2 = pd.pivot_table(df, values=['Sales', 'Units'], index='Region', columns='Product')
pivot2
# Out:
#          Sales                      Units
# Product      A      B      C      D     A     B     C     D
# Region
# East     543.2    NaN    NaN    NaN  27.0   NaN   NaN   NaN
# North      NaN    NaN  533.6    NaN   NaN   NaN  43.4   NaN
# South      NaN    NaN    NaN  456.6   NaN   NaN   NaN  45.4
# West       NaN  421.0    NaN    NaN   NaN  36.6   NaN   NaN

# %% [markdown]
# **cross tabs**

# %%
pd.crosstab(df['Region'] ,df['Product'])
# Out:
# Product  A  B  C  D
# Region
# East     5  0  0  0
# North    0  0  5  0
# South    0  0  0  5
# West     0  5  0  0
